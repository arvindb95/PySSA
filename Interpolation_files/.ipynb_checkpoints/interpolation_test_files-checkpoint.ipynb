# %%
import numpy as np
from scipy import integrate, special, interpolate
import astropy.constants as const
import astropy.units as u
import matplotlib.pyplot as plt
from astropy.table import Table
# %matplotlib widget

# %%
def calc_F(x):
    """
    Returns values of function F (defined in eq. A7 of Soderberg et al. 2005)
    at x
    """

    def fy1(y):
        return special.kv(5.0 / 3.0, y)

    if isinstance(x, float):
        return x * integrate.quad(fy1, x, np.inf)[0]
    else:
        F_x = np.zeros(len(x))
        for i, x_i in enumerate(x):
            if x_i < 699:
                F_x[i] = x_i * integrate.quad(fy1, x_i, np.inf)[0]
            else: 
                F_x[i] = 699 * integrate.quad(fy1, 699, np.inf)[0]
        return F_x

# %%
x = np.arange(0,10, 0.01)
x2 = np.arange(0,10, 0.1)
F = calc_F(x)
F2 = calc_F(x2)
# Out:
# /tmp/ipykernel_8144/1721896367.py:16: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   F_x[i] = x_i * integrate.quad(fy1, x_i, np.inf)[0]

# %%
plt.plot(x,F, label="spacing 0.01")
plt.scatter(x2, F2, color="C1", label="spacing 1")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
int_f_func = interpolate.interp1d(x2, F2, kind="cubic", fill_value="extrapolate")
interp_f = int_f_func(x)

# %%
plt.figure()
plt.plot(x, F, label = "spacing 0.01")
plt.plot(x2, F2, label = "spacing 1")
plt.plot(x, interp_f, label="interp")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = np.arange(0,700, 1e-6)
F = calc_F(x)

tab = Table([x,F], names=["x", "F"])

tab.write("F_values.txt", format="ascii", overwrite=True)
# Out:
# /tmp/ipykernel_8144/1721896367.py:16: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   F_x[i] = x_i * integrate.quad(fy1, x_i, np.inf)[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 x = np.arange(0,700, 1e-6)
# ----> 2 F = calc_F(x)
#       4 tab = Table([x,F], names=["x", "F"])
#       6 tab.write("F_values.txt", format="ascii", overwrite=True)
#
# Cell In[2], line 16, in calc_F(x)
#      14 for i, x_i in enumerate(x):
#      15     if x_i < 699:
# ---> 16         F_x[i] = x_i * integrate.quad(fy1, x_i, np.inf)[0]
#      17     else:
#      18         F_x[i] = 699 * integrate.quad(fy1, 699, np.inf)[0]
#
# File ~/micromamba/envs/astro/lib/python3.10/site-packages/scipy/integrate/_quadpack_py.py:463, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     460     return retval
#     462 if weight is None:
# --> 463     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     464                    points)
#     465 else:
#     466     if points is not None:
#
# File ~/micromamba/envs/astro/lib/python3.10/site-packages/scipy/integrate/_quadpack_py.py:577, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     575         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     576     else:
# --> 577         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     578 else:
#     579     if infbounds != 0:
#
# Cell In[2], line 8, in calc_F.<locals>.fy1(y)
#       7 def fy1(y):
# ----> 8     return special.kv(5.0 / 3.0, y)
#
# KeyboardInterrupt:

# %%
def calc_F_2(x, calc_F, p):
    """
    Returns values of function F2 (defined in eq. A7 of Soderberg et al. 2005)
    at x
    """

    def fy2(y):
        return calc_F(y) * (y ** ((p - 2.0) / 2.0))

    if isinstance(x, float):
        return np.sqrt(3) * integrate.quad(fy2, 0, x)[0]
    else:
        F_2_x = np.zeros(len(x))
        for i, x_i in enumerate(x):
            if x_i < 20000:
                F_2_x[i] = np.sqrt(3) * integrate.quad(fy2, 0, x_i)[0]
            else:
                F_2_x[i:] = np.sqrt(3) * integrate.quad(fy2, 0, 20000)[0]
        return F_2_x
